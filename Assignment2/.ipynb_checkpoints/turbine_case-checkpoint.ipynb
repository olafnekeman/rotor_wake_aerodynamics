# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from lifting_line_singular import lifting_line_model_singular
from lifting_line_general import lifting_line_model

# %% [markdown]
# # Singular rotor with airfoil polars

# %%
#turbine parameters
R = 50
N_blades = 3
mu_start = 0.2
mu_end = 1
U_0 = 10

N_blade_sec = 50      #number of blade sections
N_wake_sec_rot = 50    #number of wake sections per rotation of the rotor
N_rot = 35              #the number of rotations of the rotor NOTE needs to be integer
a_w = 0.269             #the assumed wake convection induction factor U_wake = U_0*(1-a_w)
TSR = 10
TSR_8 = 8
TSR_6 = 6

airfoil = 'DU_polar.txt' #DU_polar.txt or ARA_polar.txt

mu_vec = np.array([0.2,1.0])   #vector where chord and twist are known. NOTE beginpoint needs to be mu_start and end point mu_end

chord_vec_8 = np.array([3.726266186,0.7697521700000003]) 
twist_vec_8 = np.array([7.719046267376299,-4.7470321246237])

chord_vec = np.array([2.454897522,0.5013454500000001])
twist_vec = np.array([5.069728502187389,-5.2134756578126105])

twist_vec_6 = np.array([9.2,-2])
chord_vec_6 = np.array([3.4,1])


spacing = 'uniform'  #spacing method to use, choose from 'cosine' or 'uniform'

#intialize the class
L = lifting_line_model_singular(R, N_blades, mu_start, mu_end, mu_vec, chord_vec, twist_vec, U_0, TSR, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L.weight_step = 0.05
#L.print_progress = False
#commit all the inputs
L.commit_parameters()

L_8 = lifting_line_model_singular(R, N_blades, mu_start, mu_end, mu_vec, chord_vec_8, twist_vec_8, U_0, TSR_8, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L_8.weight_step = 0.05
#L.print_progress = False
#commit all the inputs
L_8.commit_parameters()

L_6 = lifting_line_model_singular(R, N_blades, mu_start, mu_end, mu_vec, chord_vec_6, twist_vec_6, U_0, TSR_6, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L_6.weight_step = 0.05
#L.print_progress = False
#commit all the inputs
L_6.commit_parameters()

#plot the wake of the rotor
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

colors = ['b','r','g']

for j in range(N_blades):
    ax.plot(L.blades[j].x_cp,L.blades[j].y_cp,L.blades[j].z_cp)
    for i in range(N_blade_sec+1):
        ax.plot(L.blades[j].x_wake[i,:],L.blades[j].y_wake[i,:],L.blades[j].z_wake[i,:], colors[j])

L.solve_system()

L_8.solve_system()

L_6.solve_system()
# Out:
# Initializing
# Setting up blade geometry
# mu_dist [0.2   0.216 0.232 0.248 0.264 0.28  0.296 0.312 0.328 0.344 0.36  0.376
#  0.392 0.408 0.424 0.44  0.456 0.472 0.488 0.504 0.52  0.536 0.552 0.568
#  0.584 0.6   0.616 0.632 0.648 0.664 0.68  0.696 0.712 0.728 0.744 0.76
#  0.776 0.792 0.808 0.824 0.84  0.856 0.872 0.888 0.904 0.92  0.936 0.952
#  0.968 0.984 1.   ]
# Constructing blade number 0
# mu_dist [0.2   0.216 0.232 0.248 0.264 0.28  0.296 0.312 0.328 0.344 0.36  0.376
#  0.392 0.408 0.424 0.44  0.456 0.472 0.488 0.504 0.52  0.536 0.552 0.568
#  0.584 0.6   0.616 0.632 0.648 0.664 0.68  0.696 0.712 0.728 0.744 0.76
#  0.776 0.792 0.808 0.824 0.84  0.856 0.872 0.888 0.904 0.92  0.936 0.952
#  0.968 0.984 1.   ]
# Constructing blade number 1
# mu_dist [0.2   0.216 0.232 0.248 0.264 0.28  0.296 0.312 0.328 0.344 0.36  0.376
#  0.392 0.408 0.424 0.44  0.456 0.472 0.488 0.504 0.52  0.536 0.552 0.568
#  0.584 0.6   0.616 0.632 0.648 0.664 0.68  0.696 0.712 0.728 0.744 0.76
# ...

# %%
#turbine parameters
R = 50
N_blades = 3
mu_start = 0.2
mu_end = 1
U_0 = 10

N_blade_sec = 50      #number of blade sections
N_wake_sec_rot = 50    #number of wake sections per rotation of the rotor
N_rot = 16              #the number of rotations of the rotor NOTE needs to be integer
a_w = 0.281             #the assumed wake convection induction factor U_wake = U_0*(1-a_w)
TSR = 10
TSR_8 = 8
TSR_6 = 6
a_w8 = 0.276
airfoil = 'DU_polar.txt' #DU_polar.txt or ARA_polar.txt

mu_vec = np.array([0.2,1.0])   #vector where chord and twist are known. NOTE beginpoint needs to be mu_start and end point mu_end

chord_vec_8 = np.array([3.726266186,0.7697521700000003]) 
twist_vec_8 = np.array([7.719046267376299,-4.7470321246237])

chord_vec = np.array([2.454897522,0.5013454500000001])
twist_vec = np.array([5.069728502187389,-5.2134756578126105])

twist_vec_6 = np.array([9.2,-2])
chord_vec_6 = np.array([3.4,1])


spacing = 'uniform'  #spacing method to use, choose from 'cosine' or 'uniform'

#intialize the class
L = lifting_line_model_singular(R, N_blades, mu_start, mu_end, mu_vec, chord_vec, twist_vec, U_0, TSR, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L.weight_step = 0.05
#L.print_progress = False
#commit all the inputs
L.commit_parameters()

L_8 = lifting_line_model_singular(R, N_blades, mu_start, mu_end, mu_vec, chord_vec_8, twist_vec_8, U_0, TSR_8, N_blade_sec, N_wake_sec_rot, N_rot, a_w8, airfoil, spacing = spacing)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L_8.weight_step = 0.05
#L.print_progress = False
#commit all the inputs
L_8.commit_parameters()

L.core_size = 0.02
L_8.core_size = 0.02

#plot the wake of the rotor
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

colors = ['b','r','g']

for j in range(N_blades):
    ax.plot(L.blades[j].x_cp,L.blades[j].y_cp,L.blades[j].z_cp)
    for i in range(N_blade_sec+1):
        ax.plot(L.blades[j].x_wake[i,:],L.blades[j].y_wake[i,:],L.blades[j].z_wake[i,:], colors[j])

L.solve_system()

L_8.solve_system()
# Out:
# Initializing
# Setting up blade geometry
# mu_dist [0.2   0.216 0.232 0.248 0.264 0.28  0.296 0.312 0.328 0.344 0.36  0.376
#  0.392 0.408 0.424 0.44  0.456 0.472 0.488 0.504 0.52  0.536 0.552 0.568
#  0.584 0.6   0.616 0.632 0.648 0.664 0.68  0.696 0.712 0.728 0.744 0.76
#  0.776 0.792 0.808 0.824 0.84  0.856 0.872 0.888 0.904 0.92  0.936 0.952
#  0.968 0.984 1.   ]
# Constructing blade number 0
# mu_dist [0.2   0.216 0.232 0.248 0.264 0.28  0.296 0.312 0.328 0.344 0.36  0.376
#  0.392 0.408 0.424 0.44  0.456 0.472 0.488 0.504 0.52  0.536 0.552 0.568
#  0.584 0.6   0.616 0.632 0.648 0.664 0.68  0.696 0.712 0.728 0.744 0.76
#  0.776 0.792 0.808 0.824 0.84  0.856 0.872 0.888 0.904 0.92  0.936 0.952
#  0.968 0.984 1.   ]
# Constructing blade number 1
# mu_dist [0.2   0.216 0.232 0.248 0.264 0.28  0.296 0.312 0.328 0.344 0.36  0.376
#  0.392 0.408 0.424 0.44  0.456 0.472 0.488 0.504 0.52  0.536 0.552 0.568
#  0.584 0.6   0.616 0.632 0.648 0.664 0.68  0.696 0.712 0.728 0.744 0.76
# ...

# %%
#turbine parameters
R = 50
N_blades = 3
mu_start = 0.2
mu_end = 1
U_0 = 10

N_blade_sec = 50      #number of blade sections
N_wake_sec_rot = 50    #number of wake sections per rotation of the rotor
N_rot = 16              #the number of rotations of the rotor NOTE needs to be integer
a_w = 0.281             #the assumed wake convection induction factor U_wake = U_0*(1-a_w)
TSR = 10
TSR_8 = 8
TSR_6 = 6
a_w8 = 0.276
airfoil = 'DU_polar.txt' #DU_polar.txt or ARA_polar.txt

mu_vec = np.array([0.2,1.0])   #vector where chord and twist are known. NOTE beginpoint needs to be mu_start and end point mu_end

chord_vec_8 = np.array([3.726266186,0.7697521700000003]) 
twist_vec_8 = np.array([7.719046267376299,-4.7470321246237])

chord_vec = np.array([2.454897522,0.5013454500000001])
twist_vec = np.array([5.069728502187389,-5.2134756578126105])

twist_vec_6 = np.array([9.2,-2])
chord_vec_6 = np.array([3.4,1])


spacing = 'uniform'  #spacing method to use, choose from 'cosine' or 'uniform'

#intialize the class
L = lifting_line_model_singular(R, N_blades, mu_start, mu_end, mu_vec, chord_vec, twist_vec, U_0, TSR, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L.weight_step = 0.05
#L.print_progress = False
#commit all the inputs
L.commit_parameters()


L.core_size = 0.02

#plot the wake of the rotor
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

colors = ['b','r','g']

for j in range(N_blades):
    ax.plot(L.blades[j].x_cp,L.blades[j].y_cp,L.blades[j].z_cp)
    for i in range(N_blade_sec+1):
        ax.plot(L.blades[j].x_wake[i,:],L.blades[j].y_wake[i,:],L.blades[j].z_wake[i,:], colors[j])

L.solve_system()
# Out:
# Initializing
# Setting up blade geometry
# mu_dist [0.2   0.216 0.232 0.248 0.264 0.28  0.296 0.312 0.328 0.344 0.36  0.376
#  0.392 0.408 0.424 0.44  0.456 0.472 0.488 0.504 0.52  0.536 0.552 0.568
#  0.584 0.6   0.616 0.632 0.648 0.664 0.68  0.696 0.712 0.728 0.744 0.76
#  0.776 0.792 0.808 0.824 0.84  0.856 0.872 0.888 0.904 0.92  0.936 0.952
#  0.968 0.984 1.   ]
# Constructing blade number 0
# mu_dist [0.2   0.216 0.232 0.248 0.264 0.28  0.296 0.312 0.328 0.344 0.36  0.376
#  0.392 0.408 0.424 0.44  0.456 0.472 0.488 0.504 0.52  0.536 0.552 0.568
#  0.584 0.6   0.616 0.632 0.648 0.664 0.68  0.696 0.712 0.728 0.744 0.76
#  0.776 0.792 0.808 0.824 0.84  0.856 0.872 0.888 0.904 0.92  0.936 0.952
#  0.968 0.984 1.   ]
# Constructing blade number 1
# mu_dist [0.2   0.216 0.232 0.248 0.264 0.28  0.296 0.312 0.328 0.344 0.36  0.376
#  0.392 0.408 0.424 0.44  0.456 0.472 0.488 0.504 0.52  0.536 0.552 0.568
#  0.584 0.6   0.616 0.632 0.648 0.664 0.68  0.696 0.712 0.728 0.744 0.76
# ...

# %%
#Nrot = 25
#Converged within iteration limit!
#CT = 0.7565025642272921
#CP = 0.489468072230843
#Solving problem using lift and drag polar data
#Converged within iteration limit!
#CT = 0.7558839533697327
#CP = 0.489798610798005
#Solving problem using lift and drag polar data
#Converged within iteration limit!
#CT = 0.48314583995410926
#CP = 0.3513788736815781

# Nrot = 35
#Converged within iteration limit!
#CT = 0.7563007986377007
#CP = 0.48907622449217475
#Solving problem using lift and drag polar data
#Converged within iteration limit!
#CT = 0.7557300506186376
#CP = 0.4895417308543773
#Solving problem using lift and drag polar data
#Converged within iteration limit!
#CT = 0.4831190951641291
#CP = 0.351325637210214

# 0.75580.4902

# Nblade = 40
# Converged within iteration limit!
#CT = 0.7554419208504018
#CP = 0.4874576772982182
#Solving problem using lift and drag polar data
#Converged within iteration limit!
#CT = 0.7548291602176598
#CP = 0.4880883909741362
#Solving problem using lift and drag polar data
#WARNING: Model did not converge within the convergence criteria given.
#CT = 0.48261259811829443
#CP = 0.3492913965207505

# Nblade = 50
#Converged within iteration limit!
#CT = 0.7545993617508026
#CP = 0.4862356212231337
#Solving problem using lift and drag polar data
#Converged within iteration limit!
#CT = 0.7545382586789626
#CP = 0.48794603334763864
#Solving problem using lift and drag polar data
#Converged within iteration limit!
#CT = 0.48225785075376787
#CP = 0.3496077298032196

# %%
# TSR = 8
#single_line_plot = True
#plot the wake of the rotor
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111, projection='3d')

colors = ['b','r','g', 'm', 'k', 'y']
N_blades = 1
for j in range(N_blades):
    ax.plot(L_8.blades[j].x_cp,L_8.blades[j].y_cp,L_8.blades[j].z_cp)
    for i in range(N_blade_sec+1):

        ax.plot(L_8.blades[j].x_wake[i,:],L_8.blades[j].y_wake[i,:],L_8.blades[j].z_wake[i,:], 
                colors[j], linewidth=1)

ax.view_init(30, -50-180)
ax.set_ylabel('r/R [-]')
ax.set_zlabel('r/R [-]')
ax.set_xlabel('N [-]')
ax.set_title('Lifting line model - turbine with TSR = 8')
fig.savefig("Figures_Turbine/turb_lifting_line_3d_8.png")

# TSR = 10
#plot the wake of the rotor
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111, projection='3d')

colors = ['b','r','g', 'm', 'k', 'y']
N_blades = 1
for j in range(N_blades):
    ax.plot(L.blades[j].x_cp,L.blades[j].y_cp,L.blades[j].z_cp)
    for i in range(N_blade_sec+1):

        ax.plot(L.blades[j].x_wake[i,:],L.blades[j].y_wake[i,:],L.blades[j].z_wake[i,:], 
                colors[j], linewidth=1)

ax.view_init(30, -50-180)
ax.set_ylabel('r/R [-]')
ax.set_zlabel('r/R [-]')
ax.set_xlabel('N [-]')
ax.set_title('Lifting line model - turbine with TSR = 10')
fig.savefig("Figures_Turbine/Accurate/turb_lifting_line_3d_10_single.png")

# %% [markdown]
# # Singular rotor with impermeability boundary conditions

# %%
L.print_progress= False
L.solve_system_imper()

L_8.print_progress= False
L_8.solve_system_imper()

#L_6.print_progress= False
#L_6.solve_system_imper()

# %%
plt.figure()
plt.title('Circulation')
plt.plot(L_8.blades[0].R_cent/R,L_8.blades[0].gamma_bound/(U_0**2 *np.pi)*(N_blades*U_0*TSR_8/R), 'g', label ='polar, TSR = 8')
plt.plot(L_8.blades[0].R_cent/R,L_8.blades[0].gamma_bound_imper/(U_0**2 *np.pi)*(N_blades*U_0*TSR_8/R), '--g', label ='imper, TSR = 8')
plt.plot(L.blades[0].R_cent/R,L.blades[0].gamma_bound/(U_0**2 *np.pi)*(N_blades*U_0*TSR/R), 'b', label ='polar, TSR = 10')
plt.plot(L.blades[0].R_cent/R,L.blades[0].gamma_bound_imper/(U_0**2 *np.pi)*(N_blades*U_0*TSR/R), '--b', label ='imper, TSR = 10')
plt.grid(True)
plt.xlabel('$r/R$')
plt.ylabel('$\Gamma_{bound}$')
plt.legend()
plt.savefig('Figures_Turbine/Accurate/Circulation_imper.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# %store -r results8
# %store -r results10
# %store -r chord
# %store -r dr
# %store -r r_R

# %%
# Plotting the radial distribution of angle of attack

plt.figure()
plt.title('Angle of attack')
#plt.plot(L_6.blades[0].R_cent/R,L_6.blades[0].alpha/180*np.pi, 'r', label ='TSR = 6')
#plt.plot(L_8.blades[0].R_cent/R,L_8.blades[0].alpha, 'g', label ='TSR = 8')
plt.plot(L_8.blades[0].R_cent/R,L_8.blades[0].alpha, 'g', label ='Lifting line, TSR = 8')
plt.plot(results8[:,2],results8[:,6], '--g',label='BEM, TSR = 8')
plt.plot(L.blades[0].R_cent/R,L.blades[0].alpha, 'b', label ='Lifting line, TSR = 10')
plt.plot(results10[:,2],results10[:,6], '--b',label='BEM, TSR = 10')
plt.grid(True)
plt.xlabel('$r/R$')
plt.ylabel(r'$\alpha$ [deg]')
plt.legend()
plt.savefig('Figures_Turbine/Accurate/AoA_comp.eps')

plt.figure()
plt.title('Circulation')
#plt.plot(L_6.blades[0].R_cent/R,L_6.blades[0].gamma_bound/(U_0**2 *np.pi)*(N_blades*U_0*TSR_6/R), 'r', label ='TSR = 6')
plt.plot(L_8.blades[0].R_cent/R,L_8.blades[0].gamma_bound/(U_0**2 *np.pi)*(N_blades*U_0*TSR_8/R), 'g', label ='Lifting line, TSR = 8')
plt.plot(results8[:,2],results8[:,5]/(U_0**2 *np.pi)*(N_blades*U_0*TSR_8/R), '--g',label='BEM, TSR = 8')
plt.plot(L.blades[0].R_cent/R,L.blades[0].gamma_bound/(U_0**2 *np.pi)*(N_blades*U_0*TSR/R), 'b', label ='Lifting line, TSR = 10')
plt.plot(results10[:,2],results10[:,5]/(U_0**2 *np.pi)*(N_blades*U_0*TSR/R), '--b',label='BEM, TSR = 10')
plt.grid(True)
plt.xlabel('$r/R$')
plt.ylabel('$\Gamma_{bound}$')
plt.legend()
plt.savefig('Figures_Turbine/Accurate/circulation_comp.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Plotting the radial distribution of inflow angle

plt.figure()
plt.title('Inflow angle')
#plt.plot(L_6.blades[0].R_cent/R,L_6.blades[0].inflowangle/180*np.pi, 'r', label ='TSR = 6')
plt.plot(L_8.blades[0].R_cent/R,L_8.blades[0].inflowangle*180/np.pi, 'g', label ='Lifting line, TSR = 8')
plt.plot(results8[:,2],results8[:,7], '--g',label='BEM, TSR = 8')
plt.plot(L.blades[0].R_cent/R,L.blades[0].inflowangle*180/np.pi, 'b', label ='Lifting line, TSR = 10')
plt.plot(results10[:,2],results10[:,7], '--b',label='BEM, TSR = 10')
plt.grid(True)
plt.xlabel('$r/R$')
plt.ylabel(r'$\varphi [deg]$')
plt.legend()
plt.savefig('Figures_Turbine/Accurate/Varphi_comp.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Plotting the radial distribution of axial load

rho = 1.225

plt.figure()
plt.title('Axial load')
#plt.plot(L_6.blades[0].R_cent/R,L_6.blades[0].F_T/(0.5*rho*U_0**2*R), 'r', label ='TSR = 6')
plt.plot(L_8.blades[0].R_cent/R,L_8.blades[0].F_T/(0.5*rho*U_0**2*R), 'g', label ='TSR = 8')
plt.plot(results8[:,2],results8[:,3]/(0.5*rho*U_0**2*R), '--g',label='BEM, TSR = 8')
plt.plot(L.blades[0].R_cent/R,L.blades[0].F_T/(0.5*rho*U_0**2*R), 'b', label ='TSR = 10')
plt.plot(results10[:,2],results10[:,3]/(0.5*rho*U_0**2*R), '--b',label='BEM, TSR = 10')
plt.grid(True)
plt.xlabel('$r/R$')
plt.ylabel(r'$F_{axial}$')
plt.legend()
plt.savefig('Figures_Turbine/Accurate/AxiallLoad_comp.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Plotting the radial distribution of azimuthal load

rho = 1.225

plt.figure()
plt.title('Tangential load')
#plt.plot(L_6.blades[0].R_cent/R,L_6.blades[0].F_az/(0.5*rho*U_0**2*R), 'r', label ='TSR = 6')
plt.plot(L_8.blades[0].R_cent/R,L_8.blades[0].F_az/(0.5*rho*U_0**2*R), 'g', label ='TSR = 8')
plt.plot(results8[:,2],results8[:,4]/(0.5*rho*U_0**2 *R), '--g',label='BEM, TSR = 8')
plt.plot(L.blades[0].R_cent/R,L.blades[0].F_az/(0.5*rho*U_0**2*R), 'b', label ='TSR = 10')
plt.plot(results10[:,2],results10[:,4]/(0.5*rho*U_0**2 *R), '--b',label='BEM, TSR = 10')
plt.grid(True)
plt.xlabel('$r/R$')
plt.ylabel(r'$F_{tangential}$')
plt.legend()
plt.savefig('Figures_Turbine/Accurate/AzimuthalLoad_comp.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Plotting the radial distribution of the thrust coefficient

rho = 1.225

fig1 = plt.figure()
plt.title('Induction factor')
plt.plot(L_8.blades[0].R_cent/L_8.blades[0].R, -L_8.blades[0].cp_induction_u/U_0, 'g',label='Lifting line, TSR = 8')
plt.plot(results8[:,2],results8[:,0],'--g', label='BEM, TSR = 8')
plt.plot(L.blades[0].R_cent/L.blades[0].R, -L.blades[0].cp_induction_u/U_0, 'b',label='Lifting line, TSR = 10')
plt.plot(results10[:,2],results10[:,0],'--b', label='BEM, TSR = 10')
plt.grid(True)
plt.xlabel('r/R [-]')
plt.ylabel('a [-]')
plt.ylim(bottom = 0)
plt.legend()
fig1.savefig('Figures_turbine/Accurate/induction_comp.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Two rotors

# %%
#turbine parameters
R = 50
N_blades = 3
mu_start = 0.2
mu_end = 1
U_0 = 10

N_blade_sec = 50      #number of blade sections
N_wake_sec_rot = 50    #number of wake sections per rotation of the rotor
N_rot = 35              #the number of rotations of the rotor NOTE needs to be integer
a_w = 0.281             #the assumed wake convection induction factor U_wake = U_0*(1-a_w)
TSR = 10
TSR_8 = 8
TSR_6 = 6
a_w8 = 0.276

airfoil = 'DU_polar.txt' #DU_polar.txt or ARA_polar.txt

mu_vec = np.array([0.2,1.0])   #vector where chord and twist are known. NOTE beginpoint needs to be mu_start and end point mu_end

chord_vec_8 = np.array([3.726266186,0.7697521700000003]) 
twist_vec_8 = np.array([7.719046267376299,-4.7470321246237])

chord_vec = np.array([2.454897522,0.5013454500000001])
twist_vec = np.array([5.069728502187389,-5.2134756578126105])

twist_vec_6 = np.array([9.2,-2])
chord_vec_6 = np.array([3.4,1])

spacing = 'uniform'  #spacing method to use, choose from 'cosine' or 'uniform'

#######new part
N_rotors = 2 #max is 2 currently
phase_diff = 0 #phase difference in radians, note max phase_diff = 2*pi/N_blades
location = [0,60*R]  #y-locations of the rotors

#intialize the class for two rotor case
L2 = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec, twist_vec, U_0, TSR, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff, location=location)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L2.weight_step = 0.05
L2.print_progress = False
#commit all the inputs
L2.commit_parameters()

L2.core_size = 0.02
L2.solve_system()

#print(L2.blades[0].alpha)
#print(L2.blades[1].alpha)
#print(L2.blades[2].alpha)

#intialize the class for two rotor case
L2_8 = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec_8, twist_vec_8, U_0, TSR_8, N_blade_sec, N_wake_sec_rot, N_rot, a_w8, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff, location=location)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L2_8.weight_step = 0.05
L2_8.print_progress = False
#commit all the inputs
L2_8.commit_parameters()

L2_8.core_size = 0.02
L2_8.solve_system()

#print(L2_8.blades[0].alpha)
#print(L2_8.blades[1].alpha)
#print(L2_8.blades[2].alpha)

#solve the single rotor case again for TSR=10 to compare
#L.TSR = 10
#L.print_progress = False
#L.commit_parameters()
#L.solve_system()

# %%
# Running everything
R = 50
N_blades = 3
mu_start = 0.2
mu_end = 1
U_0 = 10

N_blade_sec = 30      #number of blade sections
N_wake_sec_rot = 30    #number of wake sections per rotation of the rotor
N_rot = 5              #the number of rotations of the rotor NOTE needs to be integer
a_w = 0.25             #the assumed wake convection induction factor U_wake = U_0*(1-a_w)
TSR = 10
TSR_8 = 8
TSR_6 = 6

airfoil = 'DU_polar.txt' #DU_polar.txt or ARA_polar.txt

mu_vec = np.array([0.2,1.0])   #vector where chord and twist are known. NOTE beginpoint needs to be mu_start and end point mu_end

chord_vec_8 = np.array([3.726266186,0.7697521700000003]) 
twist_vec_8 = np.array([7.719046267376299,-4.7470321246237])

chord_vec = np.array([2.454897522,0.5013454500000001])
twist_vec = np.array([5.069728502187389,-5.2134756578126105])

twist_vec_6 = np.array([9.2,-2])
chord_vec_6 = np.array([3.4,1])

spacing = 'uniform'  #spacing method to use, choose from 'cosine' or 'uniform'

#######new part
N_rotors = 2 #max is 2 currently
phase_diff = 0 #phase difference in radians, note max phase_diff = 2*pi/N_blades
location1 = [0,2*R]  #y-locations of the rotors
location2 = [0,4*R]  #y-locations of the rotors
location3 = [0,6*R]  #y-locations of the rotors
location4 = [0,10*R]  #y-locations of the rotors
location5 = [0,20*R]  #y-locations of the rotors

#intialize the class for two rotor case
L21 = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec, twist_vec, U_0, TSR, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff, location=location1)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L21.weight_step = 0.05
L21.print_progress = False
#commit all the inputs
L21.commit_parameters()

L21.solve_system()

#intialize the class for two rotor case
L22 = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec, twist_vec, U_0, TSR, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff, location=location2)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L22.weight_step = 0.05
L22.print_progress = False
#commit all the inputs
L22.commit_parameters()

L22.solve_system()

#intialize the class for two rotor case
L23 = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec, twist_vec, U_0, TSR, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff, location=location3)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L23.weight_step = 0.05
L23.print_progress = False
#commit all the inputs
L23.commit_parameters()

L23.solve_system()

#intialize the class for two rotor case
L24 = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec, twist_vec, U_0, TSR, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff, location=location4)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L24.weight_step = 0.05
L24.print_progress = False
#commit all the inputs
L24.commit_parameters()

L24.solve_system()

#intialize the class for two rotor case
L25 = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec, twist_vec, U_0, TSR, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff, location=location5)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L25.weight_step = 0.05
L25.print_progress = False
#commit all the inputs
L25.commit_parameters()

L25.solve_system()


#intialize the class for two rotor case
L21_8 = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec_8, twist_vec_8, U_0, TSR_8, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff, location=location1)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L21_8.weight_step = 0.05
L21_8.print_progress = False
#commit all the inputs
L21_8.commit_parameters()

L21_8.solve_system()

L22_8 = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec_8, twist_vec_8, U_0, TSR_8, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff, location=location2)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L22_8.weight_step = 0.05
L22_8.print_progress = False
#commit all the inputs
L22_8.commit_parameters()

L22_8.solve_system()

L23_8 = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec_8, twist_vec_8, U_0, TSR_8, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff, location=location3)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L23_8.weight_step = 0.05
L23_8.print_progress = False
#commit all the inputs
L23_8.commit_parameters()

L23_8.solve_system()

L24_8 = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec_8, twist_vec_8, U_0, TSR_8, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff, location=location4)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L24_8.weight_step = 0.05
L24_8.print_progress = False
#commit all the inputs
L24_8.commit_parameters()

L24_8.solve_system()

L25_8 = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec_8, twist_vec_8, U_0, TSR_8, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff, location=location5)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L25_8.weight_step = 0.05
L25_8.print_progress = False
#commit all the inputs
L25_8.commit_parameters()

L25_8.solve_system()

# %%
# Running everything
R = 50
N_blades = 3
mu_start = 0.2
mu_end = 1
U_0 = 10

N_blade_sec = 30      #number of blade sections
N_wake_sec_rot = 30    #number of wake sections per rotation of the rotor
N_rot = 5              #the number of rotations of the rotor NOTE needs to be integer
a_w = 0.25             #the assumed wake convection induction factor U_wake = U_0*(1-a_w)
TSR = 10
TSR_8 = 8
TSR_6 = 6

airfoil = 'DU_polar.txt' #DU_polar.txt or ARA_polar.txt

mu_vec = np.array([0.2,1.0])   #vector where chord and twist are known. NOTE beginpoint needs to be mu_start and end point mu_end

chord_vec_8 = np.array([3.726266186,0.7697521700000003]) 
twist_vec_8 = np.array([7.719046267376299,-4.7470321246237])

chord_vec = np.array([2.454897522,0.5013454500000001])
twist_vec = np.array([5.069728502187389,-5.2134756578126105])

twist_vec_6 = np.array([9.2,-2])
chord_vec_6 = np.array([3.4,1])

spacing = 'uniform'  #spacing method to use, choose from 'cosine' or 'uniform'

#######new part
N_rotors = 2 #max is 2 currently
phase_diff1 = 0 #phase difference in radians, note max phase_diff = 2*pi/N_blades
phase_diff2 = 2*np.pi/3/3
#phase_diff3 = 2*np.pi/3*2/3
phase_diff3 = 2*np.pi/3*0.9995
#phase_diff4 = 2*np.pi/3*0.9995
location = [0,2*R]  #y-locations of the rotors

#intialize the class for two rotor case
L21p = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec, twist_vec, U_0, TSR, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff1, location=location)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L21p.weight_step = 0.05
L21p.print_progress = False
#commit all the inputs
L21p.commit_parameters()

L21p.solve_system()

#intialize the class for two rotor case
L22p = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec, twist_vec, U_0, TSR, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff2, location=location)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L22p.weight_step = 0.05
L22p.print_progress = False
#commit all the inputs
L22p.commit_parameters()

L22p.solve_system()

#intialize the class for two rotor case
L23p = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec, twist_vec, U_0, TSR, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff3, location=location)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L23p.weight_step = 0.05
L23p.print_progress = False
#commit all the inputs
L23p.commit_parameters()

L23p.solve_system()

#intialize the class for two rotor case
#L24p = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec, twist_vec, U_0, TSR, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff4, location=location)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
#L24p.weight_step = 0.05
#L24p.print_progress = False
#commit all the inputs
#L24p.commit_parameters()

#L24p.solve_system()


#intialize the class for two rotor case
L21p_8 = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec_8, twist_vec_8, U_0, TSR_8, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff1, location=location)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L21p_8.weight_step = 0.05
L21p_8.print_progress = False
#commit all the inputs
L21p_8.commit_parameters()

L21p_8.solve_system()

L22p_8 = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec_8, twist_vec_8, U_0, TSR_8, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff2, location=location)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L22p_8.weight_step = 0.05
L22p_8.print_progress = False
#commit all the inputs
L22p_8.commit_parameters()

L22p_8.solve_system()

L23p_8 = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec_8, twist_vec_8, U_0, TSR_8, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff3, location=location)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
L23p_8.weight_step = 0.05
L23p_8.print_progress = False
#commit all the inputs
L23p_8.commit_parameters()

L23p_8.solve_system()

#L24p_8 = lifting_line_model(R, N_blades, mu_start, mu_end, mu_vec, chord_vec_8, twist_vec_8, U_0, TSR_8, N_blade_sec, N_wake_sec_rot, N_rot, a_w, airfoil, spacing = spacing, N_rotors = N_rotors, phase_diff = phase_diff4, location=location)
#change an attribute of the class, in this case the update weight, if you're happy with standard value, this line can be skipped
#L24p_8.weight_step = 0.05
#L24p_8.print_progress = False
#commit all the inputs
#L24p_8.commit_parameters()

#L24p_8.solve_system()

#Converged within iteration limit!
#CT = 0.7712451187951221
#CP = 0.5148609238057303
#Converged within iteration limit!
#CT = 0.7709616287122797
#CP = 0.5142023048363444
#Converged within iteration limit!
#CT = 0.7712457436403347
#CP = 0.514862267731287
#Converged within iteration limit!
#CT = 0.7691996562345343
#CP = 0.5091517566692443
#Converged within iteration limit!
#CT = 0.7687754325470708
#CP = 0.5082825269331022
#Converged within iteration limit!
#CT = 0.7692006171015047
#CP = 0.509153461133111

#Converged within iteration limit!
#CT = 0.7712451187951221
#CP = 0.5148609238057303
#Converged within iteration limit!
#CT = 0.7708474147230066
#CP = 0.5139635737308299
#Converged within iteration limit!
#CT = 0.7711374733582699
#CP = 0.5145905153356607
#Converged within iteration limit!
#CT = 0.7712457436403347
#CP = 0.514862267731287
#Converged within iteration limit!
#CT = 0.7691996562345343
#CP = 0.5091517566692443
#Converged within iteration limit!
#CT = 0.7686059459888196
#CP = 0.5079898842911066
#Converged within iteration limit!
#CT = 0.7690429571318976
#CP = 0.5087853341055976
#Converged within iteration limit!
#CT = 0.7692006171015047
#CP = 0.509153461133111

# %%
C_p = np.zeros(6)
C_T = np.zeros(6)
C_p8 = np.zeros(6)
C_T8 = np.zeros(6)
# TSR = 10, D = 2*R
C_T[0] = 0.7712451187951221
C_p[0] = 0.5148609238057303
# TSR = 8, D = 2*R
C_T8[0] = 0.7691996562345343
C_p8[0] = 0.5091517566692443

# TSR = 10, D = 4*R
C_T[1] = 0.766174795739838
C_p[1] = 0.5079128405687635
# TSR - 8, D = 4*R
C_T8[1] = 0.7643675594289403
C_p8[1] = 0.5038570099657338

# TSR = 10, D = 10*R
C_T[2] = 0.7648008552421669
C_p[2] = 0.5053108036267946
# TSR - 8, D = 10*R
C_T8[2] = 0.7627198489868999
C_p8[2] = 0.5011972247290868

# TSR = 10, D = 20*R
C_T[3] = 0.7646894458925295
C_p[3] = 0.5050923425684852
# TSR = 8, D = 20*R
C_T8[3] = 0.762556667585934
C_p8[3] = 0.5009240728232275

# TSR = 10, D = 40*R
C_T[4] = 0.7646747980217223
C_p[4] = 0.5050635670670647
# TSR = 8, D = 40*R
C_T8[4] = 0.7625343131422535
C_p8[4] = 0.5008866597388705

# TSR = 10, D = 60*R
C_T[5] = 0.7646733043443713
C_p[5] = 0.5050606347949469
# TSR = 8, D = 60*R
C_T8[5] = 0.7625320155409753
C_p8[5] = 0.5008828137056953

# Single
#CT = 0.7646695865347474
#CP = 0.5050562617804267
#Solving problem using lift and drag polar data
#Converged within iteration limit!
#CT = 0.7625317888643242
#CP = 0.5008829542486066

# %%
#plot the wake of the two rotor case
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.view_init(40, 90)

colors = ['g','r','g']

#plot the wake structure
for k in range(2):
    a = 1
    for j in range(a):
        ax.plot(L21.blades[N_blades*k+j].x_cp,L21.blades[N_blades*k+j].y_cp,L21.blades[N_blades*k+j].z_cp)
        for i in range(N_blade_sec+1):
            ax.plot(L21.blades[N_blades*k+j].x_wake[i,:],L21.blades[N_blades*k+j].y_wake[i,:],L21.blades[N_blades*k+j].z_wake[i,:], colors[j], linewidth=1)

#fig.savefig('Figures_turbine/two_geometry_front.eps')            
#compare the results of the two rotor case with the one rotor case
#print('For the single rotor case CT = {} and the two rotor case CT = {}'.format(L.CT_polar,L2.CT_polar))
#print('For the single rotor case CP = {} and the two rotor case CP = {}'.format(L.CP_polar,L2.CP_polar))

# %%
# Plot showing the power coefficient for different locations of the rotors

Distance = [2,4,10,20,40,60]
Distance = np.array(Distance)

plt.figure()
plt.title('Power coefficient')
plt.plot(Distance/2,C_p8, 'g',label='Two turbines, TSR = 8')
plt.hlines(0.5008829542486066,0,30,'g',linestyles='dashed',label= 'Single turbine, TSR = 8')
plt.plot(Distance/2, C_p, 'b',label='Two turbines, TSR = 10')
plt.hlines(0.5050562617804267,0,30,'b',linestyles='dashed', label='Single turbine, TSR = 10')
plt.grid(True)
plt.xlabel('Distance between rotor axis as a function of the turbine diameter [-]')
plt.ylabel('$C_P$ [-]')
plt.legend()
plt.savefig('Figures_turbine/two_cp.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Plot showing the thrust coefficient for different locations of the rotors

Distance = [2,4,10,20,40,60]
Distance = np.array(Distance)

plt.figure()
plt.title('Thrust coefficient')
plt.plot(Distance/2,C_T8, 'g',label='Two turbines, TSR = 8')
plt.hlines(0.7625317888643242,0,30,'g',linestyles='dashed',label= 'Single turbine, TSR = 8')
plt.plot(Distance/2, C_T, 'b',label='Two turbines, TSR = 10')
plt.hlines(0.7646695865347474,0,30,'b',linestyles='dashed', label='Single turbine, TSR = 10')
plt.grid(True)
plt.xlabel('Distance between rotor axis as a function of the turbine diameter [-]')
plt.ylabel('$C_T$ [-]')
plt.legend()
plt.savefig('Figures_turbine/two_ct.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Plot showing the circulation for different locations of the rotors

plt.figure()
plt.title('Circulation')
#plt.plot(L_6.blades[0].R_cent/R,L_6.blades[0].gamma_bound/(U_0**2 *np.pi)*(N_blades*U_0*TSR_6/R), 'r', label ='TSR = 6')
plt.plot(L.blades[0].R_cent/R,L.blades[0].gamma_bound/(U_0**2 *np.pi)*(N_blades*U_0*TSR_8/R), 'b', label ='Single turbine')
plt.plot(L21.blades[0].R_cent/R,L21.blades[0].gamma_bound/(U_0**2 *np.pi)*(N_blades*U_0*TSR_8/R), 'r', label ='Two turbines, D = 2R')
plt.plot(L22.blades[0].R_cent/R,L22.blades[0].gamma_bound/(U_0**2 *np.pi)*(N_blades*U_0*TSR_8/R), '--g', label ='Two turbines, D = 4R')
#plt.plot(L23_8.blades[0].R_cent/R,L23_8.blades[0].gamma_bound/(U_0**2 *np.pi)*(N_blades*U_0*TSR_8/R), '.-g', label ='Lifting line, TSR = 8')
#plt.plot(L24_8.blades[0].R_cent/R,L24_8.blades[0].gamma_bound/(U_0**2 *np.pi)*(N_blades*U_0*TSR_8/R), '--g', label ='Lifting line, TSR = 8')
#plt.plot(L25_8.blades[0].R_cent/R,L25_8.blades[0].gamma_bound/(U_0**2 *np.pi)*(N_blades*U_0*TSR_8/R), 'r', label ='Lifting line, TSR = 8')
#plt.plot(L.blades[0].R_cent/R,L.blades[0].gamma_bound/(U_0**2 *np.pi)*(N_blades*U_0*TSR/R), 'b', label ='Lifting line, TSR = 10')
#plt.plot(results10[:,2],results10[:,5]/(U_0**2 *np.pi)*(N_blades*U_0*TSR/R), '--b',label='BEM, TSR = 10')
plt.grid(True)
plt.xlabel('$r/R$')
plt.ylabel('$\Gamma_{bound}$')
plt.legend()
plt.savefig('Figures_Turbine/two_circulation_10.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Plotting axial and azimuthal load for different locations of the rotors
rho = 1.225

plt.figure()
plt.title('Azimuthal load')
#plt.plot(L_6.blades[0].R_cent/R,L_6.blades[0].F_az/(0.5*rho*U_0**2*R), 'r', label ='TSR = 6')
plt.plot(L.blades[0].R_cent/R,L.blades[0].F_az/(0.5*rho*U_0**2*R), 'b', label ='Single turbine')
plt.plot(L21.blades[0].R_cent/R,L21.blades[0].F_az/(0.5*rho*U_0**2*R), 'r', label ='Two turbines, D = 2R')
plt.plot(L22.blades[0].R_cent/R,L22.blades[0].F_az/(0.5*rho*U_0**2*R), '--g', label ='Two turbines, D = 4R')
#plt.plot(L23_8.blades[0].R_cent/R,L23_8.blades[0].F_az/(0.5*rho*U_0**2*R), 'g', label ='TSR = 8')
#plt.plot(L24_8.blades[0].R_cent/R,L24_8.blades[0].F_az/(0.5*rho*U_0**2*R), 'g', label ='TSR = 8')
#plt.plot(L25_8.blades[0].R_cent/R,L25_8.blades[0].F_az/(0.5*rho*U_0**2*R), 'g', label ='TSR = 8')
#plt.plot(results8[:,2],results8[:,4]/(0.5*rho*U_0**2*R), '--g',label='BEM, TSR = 8')
#plt.plot(results10[:,2],results10[:,4]/(0.5*rho*U_0**2*R), '--b',label='BEM, TSR = 10')
plt.grid(True)
plt.xlabel('$r/R$')
plt.ylabel(r'$F_{azimuthall}$')
plt.legend()
plt.savefig('Figures_Turbine/two_azimuthal_10.eps')

plt.figure()
plt.title('Axial load')
#plt.plot(L_6.blades[0].R_cent/R,L_6.blades[0].F_az/(0.5*rho*U_0**2*R), 'r', label ='TSR = 6')
plt.plot(L_8.blades[0].R_cent/R,L_8.blades[0].F_T/(0.5*rho*U_0**2*R), 'b', label ='Single turbine')
plt.plot(L21_8.blades[0].R_cent/R,L21_8.blades[0].F_T/(0.5*rho*U_0**2*R), 'r', label ='Two turbines, D = 4R')
plt.plot(L22_8.blades[0].R_cent/R,L22_8.blades[0].F_T/(0.5*rho*U_0**2*R), '--g', label ='Two turbines, D = 4R')
#plt.plot(L23_8.blades[0].R_cent/R,L23_8.blades[0].F_T/(0.5*rho*U_0**2*R), 'g', label ='TSR = 8')
#plt.plot(L24_8.blades[0].R_cent/R,L24_8.blades[0].F_T/(0.5*rho*U_0**2*R), 'g', label ='TSR = 8')
#plt.plot(L25_8.blades[0].R_cent/R,L25_8.blades[0].F_T/(0.5*rho*U_0**2*R), 'g', label ='TSR = 8')
#plt.plot(results8[:,2],results8[:,4]/(0.5*rho*U_0**2*R), '--g',label='BEM, TSR = 8')
#plt.plot(results10[:,2],results10[:,4]/(0.5*rho*U_0**2*R), '.b',label='BEM, TSR = 10')
plt.grid(True)
plt.xlabel('$r/R$')
plt.ylabel(r'$F_{axial}$')
plt.legend()
plt.savefig('Figures_Turbine/two_axial.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Plotting inflow angle for different locations of the rotors

plt.figure()
plt.title('Inflow angle')
#plt.plot(L_6.blades[0].R_cent/R,L_6.blades[0].inflowangle/180*np.pi, 'r', label ='TSR = 6')
plt.plot(L_8.blades[0].R_cent/R,L_8.blades[0].inflowangle*180/np.pi, 'b', label ='Single turbine')
plt.plot(L21_8.blades[0].R_cent/R,L21_8.blades[0].inflowangle*180/np.pi, 'r', label ='Two turbines, D = 2R')
plt.plot(L22_8.blades[0].R_cent/R,L22_8.blades[0].inflowangle*180/np.pi, '--g', label ='Two turbines, D = 4R')
#plt.plot(L23_8.blades[0].R_cent/R,L23_8.blades[0].inflowangle*180/np.pi, 'g', label ='Lifting line, TSR = 8')
#plt.plot(L24_8.blades[0].R_cent/R,L24_8.blades[0].inflowangle*180/np.pi, 'g', label ='Lifting line, TSR = 8')
#plt.plot(L25_8.blades[0].R_cent/R,L25_8.blades[0].inflowangle*180/np.pi, 'g', label ='Lifting line, TSR = 8')
plt.grid(True)
plt.xlabel('$r/R$')
plt.ylabel(r'$\varphi [deg]$')
plt.legend()
plt.savefig('Figures_Turbine/two_varphi.eps')

plt.figure()
plt.title('Inflow angle')
#plt.plot(L_6.blades[0].R_cent/R,L_6.blades[0].inflowangle/180*np.pi, 'r', label ='TSR = 6')
plt.plot(L.blades[0].R_cent/R,L.blades[0].inflowangle*180/np.pi, 'b', label ='Single turbine')
plt.plot(L21.blades[0].R_cent/R,L21.blades[0].inflowangle*180/np.pi, 'r', label ='Two turbines, D = 2R')
plt.plot(L22.blades[0].R_cent/R,L22.blades[0].inflowangle*180/np.pi, '--g', label ='Two turbines, D = 4R')
#plt.plot(L23_8.blades[0].R_cent/R,L23_8.blades[0].inflowangle*180/np.pi, 'g', label ='Lifting line, TSR = 8')
#plt.plot(L24_8.blades[0].R_cent/R,L24_8.blades[0].inflowangle*180/np.pi, 'g', label ='Lifting line, TSR = 8')
#plt.plot(L25_8.blades[0].R_cent/R,L25_8.blades[0].inflowangle*180/np.pi, 'g', label ='Lifting line, TSR = 8')
plt.grid(True)
plt.xlabel('$r/R$')
plt.ylabel(r'$\varphi [deg]$')
plt.legend()
#plt.savefig('Figures_Turbine/two_varphi.eps')

plt.figure()
plt.title('Angle of attack')
#plt.plot(L_6.blades[0].R_cent/R,L_6.blades[0].inflowangle/180*np.pi, 'r', label ='TSR = 6')
plt.plot(L_8.blades[0].R_cent/R,L_8.blades[0].alpha, 'b', label ='Single turbine')
plt.plot(L21_8.blades[0].R_cent/R,L21_8.blades[0].alpha, 'r', label ='Two turbines, D = 2R')
plt.plot(L22_8.blades[0].R_cent/R,L22_8.blades[0].alpha, '--g', label ='Two turbines, D = 4R')
#plt.plot(L23_8.blades[0].R_cent/R,L23_8.blades[0].inflowangle*180/np.pi, 'g', label ='Lifting line, TSR = 8')
#plt.plot(L24_8.blades[0].R_cent/R,L24_8.blades[0].inflowangle*180/np.pi, 'g', label ='Lifting line, TSR = 8')
#plt.plot(L25_8.blades[0].R_cent/R,L25_8.blades[0].inflowangle*180/np.pi, 'g', label ='Lifting line, TSR = 8')
plt.grid(True)
plt.xlabel('$r/R$')
plt.ylabel(r'$\alpha [deg]$')
plt.legend()
#plt.savefig('Figures_Turbine/two_alpha.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# PHASE DIFFERENCE:

C_pp = np.zeros(3)
C_Tp = np.zeros(3)
C_p8p = np.zeros(3)
C_T8p = np.zeros(3)
# TSR = 10, D = 2*R
C_Tp[0] = L21p.CT_polar
C_pp[0] = L21p.CP_polar
# TSR = 8, D = 2*R
C_T8p[0] = L21p_8.CT_polar
C_p8p[0] = L21p_8.CP_polar

# TSR = 10, D = 4*R
C_Tp[1] = L22p.CT_polar
C_pp[1] = L22p.CP_polar
# TSR - 8, D = 4*R
C_T8p[1] = L22p_8.CT_polar
C_p8p[1] = L22p_8.CP_polar

# TSR = 10, D = 10*R
C_Tp[2] = L23p.CT_polar
C_pp[2] = L23p.CP_polar
# TSR - 8, D = 10*R
C_T8p[2] = L23p_8.CT_polar
C_p8p[2] = L23p_8.CP_polar

# TSR = 10, D = 10*R
#C_Tp[3] = L24p.CT_polar
#C_pp[3] = L24p.CP_polar
# TSR - 8, D = 10*R
#C_T8p[3] = L24p_8.CT_polar
#C_p8p[3] = L24p_8.CP_polar

# %%
# phase difference plot
Phase = [0,2*np.pi/3/2, 2*np.pi/3]
#Phase = [0,2*np.pi/3/3, 2*np.pi/3*2/3,2*np.pi/3]
Phase = np.array(Phase)

# power coefficient
plt.figure()
plt.title('Power coefficient')
plt.plot(Phase,C_p8p, 'g',label='TSR = 8')
#plt.hlines(0.5008829542486066,0,np.pi*2/3,'g',linestyles='dashed',label= 'Single turbine, TSR = 8')
plt.plot(Phase, C_pp, 'b',label='TSR = 10')
#plt.hlines(0.5050562617804267,0,np.pi*2/3,'b',linestyles='dashed', label='Single turbine, TSR = 10')
plt.grid(True)
plt.xlabel('Phase difference $\phi$[rad]')
plt.ylabel('$C_P$ [-]')
plt.legend()
plt.savefig('Figures_turbine/two_cp_phase.eps')

# thrust coefficient
plt.figure()
plt.title('Thrust coefficient')
plt.plot(Phase,C_T8p, 'g',label='TSR = 8')
#plt.hlines(0.7625317888643242,0,np.pi*2/3,'g',linestyles='dashed',label= 'Single turbine, TSR = 8')
plt.plot(Phase, C_Tp, 'b',label='TSR = 10')
#plt.hlines(0.7646695865347474,0,np.pi*2/3,'b',linestyles='dashed', label='Single turbine, TSR = 10')
plt.grid(True)
plt.xlabel('Phase difference $\phi$[rad]]')
plt.ylabel('$C_T$ [-]')
plt.legend()
plt.savefig('Figures_turbine/two_ct_phase.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# inflow angle

plt.figure()
plt.title('Angle of attack')
#plt.plot(L_8.blades[0].R_cent/R,L_8.blades[0].alpha, 'b', label ='Single turbine')
plt.plot(L21p_8.blades[0].R_cent/R,L21p_8.blades[0].alpha, 'r', label ='Two turbines, $\phi$ = 0')
plt.plot(L22p_8.blades[0].R_cent/R,L22p_8.blades[0].alpha, '--g', label ='Two turbines, $\phi$ = $\pi/3$')
plt.plot(L23p_8.blades[0].R_cent/R,L23p_8.blades[0].alpha, '.b', label ='Two turbines, $\phi$ = $2\pi/3$')
#plt.plot(L24p_8.blades[0].R_cent/R,L24p_8.blades[0].alpha, '.b', label ='Two turbines, $\phi$ = $2\pi/3$')
plt.grid(True)
plt.xlabel('$r/R$')
plt.ylabel(r'$\alpha [deg]$')
plt.legend()
plt.savefig('Figures_Turbine/two_alpha_phase.eps')

plt.figure()
plt.title('Inflow angle')
#plt.plot(L.blades[0].R_cent/R,L.blades[0].inflowangle*180/np.pi, 'b', label ='Single turbine')
plt.plot(L21p_8.blades[0].R_cent/R,L21_8.blades[0].inflowangle*180/np.pi, 'r', label ='Two turbines, $\phi$ = 0')
plt.plot(L22p_8.blades[0].R_cent/R,L22_8.blades[0].inflowangle*180/np.pi, '--g', label ='Two turbines, $\phi$ = $\pi/3$')
plt.plot(L23p_8.blades[0].R_cent/R,L23_8.blades[0].inflowangle*180/np.pi, '.b', label ='Two turbines, $\phi$ = $2\pi/3$')
#plt.plot(L24p.blades[0].R_cent/R,L24.blades[0].inflowangle*180/np.pi, '.b', label ='Two turbines, D = 4R')
plt.grid(True)
plt.xlabel('$r/R$')
plt.ylabel(r'$\varphi [deg]$')
plt.legend()
plt.savefig('Figures_Turbine/two_varphi_phase.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# plotting axial, azimuthal load and circulation
# Plotting axial and azimuthal load for different locations of the rotors
rho = 1.225

plt.figure()
plt.title('Azimuthal load')
#plt.plot(L_6.blades[0].R_cent/R,L_6.blades[0].F_az/(0.5*rho*U_0**2*R), 'r', label ='TSR = 6')
#plt.plot(L_8.blades[0].R_cent/R,L_8.blades[0].F_az/(0.5*rho*U_0**2*R), 'b', label ='Single turbine')
plt.plot(L21p_8.blades[0].R_cent/R,L21p_8.blades[0].F_az/(0.5*rho*U_0**2*R), 'r', label ='Two turbines, $\phi$ = 0')
plt.plot(L22p_8.blades[0].R_cent/R,L22p_8.blades[0].F_az/(0.5*rho*U_0**2*R), '--g', label ='Two turbines, $\phi$ = $\pi/3$')
plt.plot(L23p_8.blades[0].R_cent/R,L23p_8.blades[0].F_az/(0.5*rho*U_0**2*R), '.b', label = 'Two turbines, $\phi$ = $2\pi/3$')
plt.grid(True)
plt.xlabel('$r/R$')
plt.ylabel(r'$F_{azimuthal}$')
plt.legend()
plt.savefig('Figures_Turbine/two_azimuthal_phase.eps')

plt.figure()
plt.title('Axial load')
#plt.plot(L_6.blades[0].R_cent/R,L_6.blades[0].F_az/(0.5*rho*U_0**2*R), 'r', label ='TSR = 6')
#plt.plot(L_8.blades[0].R_cent/R,L_8.blades[0].F_T/(0.5*rho*U_0**2*R), 'b', label ='Single turbine')
plt.plot(L21p_8.blades[0].R_cent/R,L21p_8.blades[0].F_T/(0.5*rho*U_0**2*R), 'r', label ='Two turbines, $\phi$ = 0')
plt.plot(L22p_8.blades[0].R_cent/R,L22p_8.blades[0].F_T/(0.5*rho*U_0**2*R), '--g', label ='Two turbines, $\phi$ = $\pi/3$')
plt.plot(L23p_8.blades[0].R_cent/R,L23p_8.blades[0].F_T/(0.5*rho*U_0**2*R), '.b', label ='Two turbines, $\phi$ = $2\pi/3$')
plt.grid(True)
plt.xlabel('$r/R$')
plt.ylabel(r'$F_{axial}$')
plt.legend()
plt.savefig('Figures_Turbine/two_axial_phase.eps')

plt.figure()
plt.title('Circulation')
#plt.plot(L_8.blades[0].R_cent/R,L_8.blades[0].gamma_bound/(U_0**2 *np.pi)*(N_blades*U_0*TSR_8/R), 'b', label ='Single turbine')
plt.plot(L21p_8.blades[0].R_cent/R,L21p_8.blades[0].gamma_bound/(U_0**2 *np.pi)*(N_blades*U_0*TSR_8/R), 'r', label ='Two turbines, $\phi$ = 0')
plt.plot(L22p_8.blades[0].R_cent/R,L22p_8.blades[0].gamma_bound/(U_0**2 *np.pi)*(N_blades*U_0*TSR_8/R), '--g', label ='Two turbines, $\phi$ = $\pi/3$')
plt.plot(L23p_8.blades[0].R_cent/R,L23p_8.blades[0].gamma_bound/(U_0**2 *np.pi)*(N_blades*U_0*TSR_8/R), '.b', label ='Two turbines, $\phi$ = $2\pi/3$')
plt.grid(True)
plt.xlabel('$r/R$')
plt.ylabel('$\Gamma_{bound}$')
plt.legend()
plt.savefig('Figures_Turbine/two_circulation_phase.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
print(mu_dist)

# %%
C_pp
# Out:
# array([0.51486092, 0.51396357, 0.51486227])

# %%
L21_8.blades[0].inflowangle*180/np.pi
# Out:
# array([15.92192812, 21.39631901, 20.64780735, 16.11306798, 15.25955094,
#        14.38471946, 13.53786273, 12.7616521 , 12.05247537, 11.39950972,
#        10.80203918, 10.254458  ,  9.75258731,  9.29252802,  8.8703466 ,
#         8.48211935,  8.12605387,  7.79921284,  7.49942272,  7.2244703 ,
#         6.97305259,  6.74505331,  6.53597175,  6.35038979,  6.17585987,
#         6.019355  ,  5.8510756 ,  5.60980719,  5.07731532,  3.39684854])

# %%
mu_dist

# %%
L.blades[0].mu_dist

# %%
L.blades[0].gamma_bound

# %%
L.blades[0].gamma_bound*U_0

# %%
np.pi

# %%
pi

# %%
TSR/R

# %%
R

# %%
mu_vec

# %%
R_cent

# %%
L.blades[0].R_cent

# %%
U_0**2 *np.pi

# %%
R

# %%
TSR/R

# %%
TSR_6/R

# %%
L_8.blades[0].gamma_bound

# %%
L_8.blades[0].gamma_bound/(U_0**2 *np.pi)*(2*TSR_8/R)

# %%
L_8.blades[0].gamma_bound/(U_0 *np.pi)*(2*TSR_8/R)

# %%
L.blades[0].Omega

# %%
L.blades[0].alpha

# %%
L.blades[0].omega

# %%
L.blades[0].Omega

# %%
np.array([0.77,3.73])

# %%
np.array([0.2,1.0])

# %%
np.pi
# Out:
# 3.141592653589793

# %%
L.core_size
# Out:
# 0.25

# %%
L.core_size = 0.02

# %%
L.core_size = 0.02

# %%
L.core_size
# Out:
# 0.02
